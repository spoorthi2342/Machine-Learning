# %%
import numpy as np
import pandas as pd

# Load the dataset
data = pd.DataFrame(data=pd.read_csv('enjoysport.csv'))

# Extract the concepts (features) and the target (class labels)
concepts = np.array(data.iloc[:, 0:-1])
print("Concepts (features):")
print(concepts)

target = np.array(data.iloc[:, -1])
print("\nTarget (class labels):")
print(target)

def learn(concepts, target):
    # Initialize the specific hypothesis to the first instance
    specific_h = concepts[0].copy()
    print("\nInitialization of specific_h and general_h")
    print("Initial specific hypothesis (specific_h):")
    print(specific_h)
    
    # Initialize the general hypothesis to the most general hypothesis
    general_h = [["?" for i in range(len(specific_h))] for i in range(len(specific_h))]
    print("Initial general hypothesis (general_h):")
    print(general_h)
    
    # Iterate through each instance and its corresponding target value
    for i, h in enumerate(concepts):
        # If the target value is "yes", adjust the specific hypothesis
        if target[i] == "yes":
            for x in range(len(specific_h)):
                if h[x] != specific_h[x]:
                    specific_h[x] = '?'
                    general_h[x][x] = '?'
            print("Specific hypothesis after instance", i+1, ":")
            print(specific_h)
        
        # If the target value is "no", adjust the general hypothesis
        if target[i] == "no":
            for x in range(len(specific_h)):
                if h[x] != specific_h[x]:
                    general_h[x][x] = specific_h[x]
                else:
                    general_h[x][x] = '?'
        print("\nSteps of Candidate Elimination Algorithm after instance", i+1)
        print("Specific hypothesis (specific_h):")
        print(specific_h)
        print("General hypothesis (general_h):")
        print(general_h)
        
    # Remove the most general hypotheses from the general hypothesis
    indices = [i for i, val in enumerate(general_h) if val == ['?', '?', '?', '?', '?', '?']]
    
    for i in indices:
        general_h.remove(['?', '?', '?', '?', '?', '?'])
        
    return specific_h, general_h
    
# Execute the learning function
s_final, g_final = learn(concepts, target)

# Display the final specific and general hypotheses
print("\nFinal Specific_h:", s_final, sep="\n")
print("\nFinal General_h:", g_final, sep="\n")
# Out:
# Concepts (features):
# [['sunny' 'warm' 'normal' 'strong' 'warm' 'same']
#  ['sunny' 'warm' 'high' 'strong' 'warm' 'same']
#  ['rainy' 'cold' 'high' 'strong' 'warm' 'change']
#  ['sunny' 'warm' 'high' 'strong' 'cool' 'change']]
#
# Target (class labels):
# ['yes' 'yes' 'no' 'yes']
#
# Initialization of specific_h and general_h
# Initial specific hypothesis (specific_h):
# ['sunny' 'warm' 'normal' 'strong' 'warm' 'same']
# Initial general hypothesis (general_h):
# [['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?']]
# Specific hypothesis after instance 1 :
# ['sunny' 'warm' 'normal' 'strong' 'warm' 'same']
#
# Steps of Candidate Elimination Algorithm after instance 1
# Specific hypothesis (specific_h):
# ['sunny' 'warm' 'normal' 'strong' 'warm' 'same']
# General hypothesis (general_h):
# [['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?']]
# Specific hypothesis after instance 2 :
# ['sunny' 'warm' '?' 'strong' 'warm' 'same']
#
# Steps of Candidate Elimination Algorithm after instance 2
# Specific hypothesis (specific_h):
# ['sunny' 'warm' '?' 'strong' 'warm' 'same']
# General hypothesis (general_h):
# [['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?']]
#
# Steps of Candidate Elimination Algorithm after instance 3
# Specific hypothesis (specific_h):
# ['sunny' 'warm' '?' 'strong' 'warm' 'same']
# General hypothesis (general_h):
# [['sunny', '?', '?', '?', '?', '?'], ['?', 'warm', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', 'same']]
# Specific hypothesis after instance 4 :
# ['sunny' 'warm' '?' 'strong' '?' '?']
#
# Steps of Candidate Elimination Algorithm after instance 4
# Specific hypothesis (specific_h):
# ['sunny' 'warm' '?' 'strong' '?' '?']
# General hypothesis (general_h):
# [['sunny', '?', '?', '?', '?', '?'], ['?', 'warm', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?']]
#
# Final Specific_h:
# ['sunny' 'warm' '?' 'strong' '?' '?']
#
# Final General_h:
# [['sunny', '?', '?', '?', '?', '?'], ['?', 'warm', '?', '?', '?', '?']]
